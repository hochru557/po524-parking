# %%
import pandas as pd
import requests,csv
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/hoperuse/Projects/po524-parking/City Policies Coded.csv')
df
# Out:
#                                              StartDate  \
# 0                                           Start Date
# 1    {"ImportId":"startDate","timeZone":"America/Ne...
# 2                                      2/13/2022 20:24
# 3                                      2/15/2022 14:53
# 4                                      2/15/2022 14:54
# ..                                                 ...
# 148                                    3/29/2022 11:29
# 149                                    3/29/2022 11:44
# 150                                    3/29/2022 11:51
# 151                                    3/29/2022 14:14
# 152                                    3/29/2022 16:49
#
#                                                EndDate                 Status  \
# 0                                             End Date          Response Type
# 1    {"ImportId":"endDate","timeZone":"America/New_...  {"ImportId":"status"}
# ...

# %%
df.loc[df.Q2 == '1 - New England cities over 20K']
# Out:
#            StartDate          EndDate          Status        IPAddress  \
# 3    2/15/2022 14:53  2/15/2022 14:57  Survey Preview              NaN
# 12   2/15/2022 14:58  2/15/2022 15:10  Survey Preview              NaN
# 15   2/15/2022 15:02  2/15/2022 15:11  Survey Preview              NaN
# 19   2/15/2022 15:02  2/15/2022 15:52  Survey Preview              NaN
# 27   3/15/2022 14:18  3/15/2022 15:01      IP Address  168.122.220.195
# 58   3/20/2022 12:49  3/20/2022 12:52      IP Address     24.62.76.173
# 105  3/15/2022 14:30  3/22/2022 14:34      IP Address    155.41.86.171
# 106  3/22/2022 14:23  3/22/2022 14:35  Survey Preview              NaN
# 107  3/15/2022 14:22  3/22/2022 14:35      IP Address   168.122.14.208
# 108  3/22/2022 14:36  3/22/2022 14:41      IP Address    155.41.86.171
# 109  3/15/2022 14:30  3/22/2022 14:42      IP Address    155.41.71.129
# 110  3/22/2022 14:35  3/22/2022 14:48  Survey Preview              NaN
# ...
