# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/hoperuse/Projects/po524-parking/311_service_requests_2019.csv')
gb = df.groupby(by='neighborhood')
gb.get_group('Dorchester')
# Out:
#         case_enquiry_id              open_dt            target_dt  \
# 0          101002767856  2019-01-01 00:04:32  2019-01-03 08:30:00
# 3          101002767861  2019-01-01 01:26:00                  NaN
# 4          101002767862  2019-01-01 01:33:09  2019-01-03 08:30:00
# 10         101002767870  2019-01-01 03:31:55  2019-01-03 08:30:00
# 12         101002767873  2019-01-01 04:59:57  2019-01-03 08:30:00
# ...                 ...                  ...                  ...
# 259462     101003148189  2019-12-31 19:19:42  2020-01-03 08:30:00
# 259476     101003148209  2019-12-31 20:00:00  2020-01-03 08:30:00
# 259481     101003148218  2019-12-31 20:55:55  2020-01-03 08:30:00
# 259488     101003148227  2019-12-31 22:13:10  2020-01-03 08:30:00
# 259489     101003148228  2019-12-31 22:35:00  2020-01-03 08:30:00
#
#                   closed_dt  ontime case_status  \
# 0       2019-01-02 02:22:29  ONTIME      Closed
# 3       2019-05-17 12:27:07  ONTIME      Closed
# ...

# %%
import datetime
df.dtypes
# Out:
# case_enquiry_id                     int64
# open_dt                            object
# target_dt                          object
# closed_dt                          object
# ontime                             object
# case_status                        object
# closure_reason                     object
# case_title                         object
# subject                            object
# reason                             object
# type                               object
# queue                              object
# department                         object
# submittedphoto                     object
# closedphoto                        object
# location                           object
# fire_district                      object
# pwd_district                       object
# city_council_district              object
# police_district                    object
# neighborhood                       object
# neighborhood_services_district     object
# ...
